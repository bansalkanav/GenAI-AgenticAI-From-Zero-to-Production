# %% [markdown]
# ### **Tools**
#
# Migrating to create_agent(): https://docs.langchain.com/oss/python/migrate/langchain-v1#migrate-to-create-agent
#
# Custom Tool Properties: https://docs.langchain.com/oss/python/langchain/tools#customize-tool-properties
#
# Schema Definition: https://docs.langchain.com/oss/python/langchain/tools#advanced-schema-definition
#
# Accessing Context: https://docs.langchain.com/oss/python/langchain/tools#accessing-context
#
# Runtime Context: https://docs.langchain.com/oss/python/langchain/runtime
#
# Read/Write short-term memory from tool: https://docs.langchain.com/oss/python/langchain/short-term-memory#write-short-term-memory-from-tools

# %% [markdown]
# #### **Streaming**
#
# https://docs.langchain.com/oss/python/langchain/streaming

# %% [markdown]
# ### **Context Engineering (Model, Tool and Lifecycle)**
#
# LangChain middleware is the mechanism under the hood that makes context engineering practical for developers using LangChain.
#
# https://docs.langchain.com/oss/python/langchain/context-engineering

# %%
from langchain.tools import tool

@tool
def check_weather():
    "This check the weather"
    return "Hot"

# %%
from langchain_openai import ChatOpenAI

# Setup API Key
f = open('keys/.openai_api_key.txt')
OPENAI_API_KEY = f.read()

llm = ChatOpenAI(openai_api_key=OPENAI_API_KEY,
                 model="gpt-4o-mini",
                 temperature=0.0)

# %%
from langchain.messages import SystemMessage
from langchain.agents import create_agent

agent = create_agent(
    model=llm,
    tools=[check_weather],
    system_prompt=SystemMessage(content="You are a helpful assistant")
)

# %%
SystemMessage(content="You are a helpful assistant").to_string()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 SystemMessage(content="You are a helpful assistant").to_string()
#
# File ~/Developer/.env_langchain/lib/python3.13/site-packages/pydantic/main.py:1026, in BaseModel.__getattr__(self, item)
#    1023     return super().__getattribute__(item)  # Raises AttributeError if appropriate
#    1024 else:
#    1025     # this is the current error
# -> 1026     raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}')
#
# AttributeError: 'SystemMessage' object has no attribute 'to_string'
