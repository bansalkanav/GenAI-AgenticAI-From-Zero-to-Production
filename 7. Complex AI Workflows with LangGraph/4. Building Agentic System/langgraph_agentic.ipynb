# %%
from langgraph.graph import MessagesState, StateGraph, START, END
from langgraph.prebuilt import ToolNode, tools_condition

# %%
# State that holds conversation history
class MyMessagesState(MessagesState):
    pass

# %%
# Node: the AI generates a response and may call a tool
def tool_calling_llm(state: MyMessagesState):
    response = llm_with_tools.invoke(state["messages"])
    return {"messages": [response]}

# %%
# Tools
def multiply(a: int, b: int) -> int:
    """Multiply two integers and return the product."""
    return a * b

def translate_to_french(text: str) -> str:
    """Return a mock French translation of the input text."""
    return f"French translation of '{text}'"

def get_weather(city: str) -> str:
    """Return a mock weather string for the given city."""
    return f"The weather in {city} is sunny."

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5")

# Bind all tools
llm_with_tools = llm.bind_tools([multiply, translate_to_french, get_weather])
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[9], line 3
#       1 from langchain_openai import ChatOpenAI
# ----> 3 llm = ChatOpenAI(model="gpt-5")
#       5 # Bind all tools
#       6 llm_with_tools = llm.bind_tools([multiply, translate_to_french, get_weather])
#
# File ~/Developer/.env_langchain/lib/python3.13/site-packages/langchain_core/load/serializable.py:116, in Serializable.__init__(self, *args, **kwargs)
#     114 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     115     """"""  # noqa: D419  # Intentional blank docstring
# --> 116     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~/Developer/.env_langchain/lib/python3.13/site-packages/langchain_openai/chat_models/base.py:964, in BaseChatOpenAI.validate_environment(self)
#     954         self.http_async_client = httpx.AsyncClient(
#     955             proxy=self.openai_proxy, verify=global_ssl_context
#     956         )
#     957     async_specific = {
#     958         "http_client": self.http_async_client
#     959         or _get_default_async_httpx_client(
#    (...)    962         "api_key": async_api_key_value,
#     963     }
# --> 964     self.root_async_client = openai.AsyncOpenAI(
#     965         **client_params,
#     966         **async_specific,  # type: ignore[arg-type]
#     967     )
#     968     self.async_client = self.root_async_client.chat.completions
#     969 return self
#
# File ~/Developer/.env_langchain/lib/python3.13/site-packages/openai/_client.py:488, in AsyncOpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     486     api_key = os.environ.get("OPENAI_API_KEY")
#     487 if api_key is None:
# --> 488     raise OpenAIError(
#     489         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     490     )
#     491 if callable(api_key):
#     492     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
# Build the graph
builder = StateGraph(MyMessagesState)

# Add nodes
builder.add_node("tool_calling_llm", tool_calling_llm)
builder.add_node("tools", ToolNode([multiply, translate_to_french, get_weather]))

# Connect nodes
builder.add_edge(START, "tool_calling_llm")
builder.add_conditional_edges("tool_calling_llm", tools_condition)
builder.add_edge("tools", END)

# %%
# Compile
graph = builder.compile()
